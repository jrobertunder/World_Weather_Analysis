# %%
# Import the random module.
import random
import pandas as pd
import numpy as np
import timeit
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
import time
from datetime import datetime
# datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')

# %%
# # Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
coordinates = list(zip(lats, lngs))

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 623

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# # Loop through all the cities in our list.
# for i in range(len(cities)):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | lagoa
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | mizan teferi
# Processing Record 9 of Set 1 | naze
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | los llanos de aridane
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | gizo
# Processing Record 17 of Set 1 | vestmannaeyjar
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | tevaitoa
# Processing Record 20 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 1 | chuy
# Processing Record 22 of Set 1 | coquimbo
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | sioux lookout
# Processing Record 25 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | luganville
# Processing Record 32 of Set 1 | karasjok
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | velsen
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 1 | tias
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | esmeralda
# Processing Record 45 of Set 1 | yenagoa
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | morondava
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | hofn
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | rudbar
# Processing Record 2 of Set 2 | port-cartier
# Processing Record 3 of Set 2 | nabire
# Processing Record 4 of Set 2 | jardim
# Processing Record 5 of Set 2 | batemans bay
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | outjo
# Processing Record 8 of Set 2 | mercedes
# Processing Record 9 of Set 2 | mankono
# Processing Record 10 of Set 2 | penzance
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | atambua
# Processing Record 15 of Set 2 | norman wells
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | saint-augustin
# Processing Record 18 of Set 2 | sibolga
# Processing Record 19 of Set 2 | tasiilaq
# Processing Record 20 of Set 2 | ilhabela
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | kaka
# Processing Record 24 of Set 2 | hamilton
# Processing Record 25 of Set 2 | amapa
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | beloha
# Processing Record 30 of Set 2 | labuan
# Processing Record 31 of Set 2 | kiboga
# Processing Record 32 of Set 2 | avera
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | sol-iletsk
# Processing Record 35 of Set 2 | tigil
# Processing Record 36 of Set 2 | peachland
# Processing Record 37 of Set 2 | laguna
# Processing Record 38 of Set 2 | ulaangom
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | piracicaba
# Processing Record 41 of Set 2 | rio grande
# Processing Record 42 of Set 2 | itarema
# Processing Record 43 of Set 2 | crotone
# Processing Record 44 of Set 2 | berlevag
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | mantua
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | bad kreuznach
# Processing Record 49 of Set 2 | namatanai
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | piacabucu
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | emporia
# Processing Record 4 of Set 3 | saint-francois
# Processing Record 5 of Set 3 | chokurdakh
# Processing Record 6 of Set 3 | palomares
# Processing Record 7 of Set 3 | roma
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | pochutla
# Processing Record 10 of Set 3 | morant bay
# Processing Record 11 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 3 | yulara
# Processing Record 13 of Set 3 | kampot
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | karachi
# Processing Record 16 of Set 3 | rockhampton
# Processing Record 17 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 3 | alanya
# Processing Record 19 of Set 3 | zyryanka
# Processing Record 20 of Set 3 | tautira
# Processing Record 21 of Set 3 | dakar
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | vanimo
# Processing Record 24 of Set 3 | hudson bay
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | sao jose da coroa grande
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 3 | mamala
# Processing Record 31 of Set 3 | charlottetown
# Processing Record 32 of Set 3 | guozhen
# Processing Record 33 of Set 3 | qandala
# Processing Record 34 of Set 3 | great yarmouth
# Processing Record 35 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 3 | kotelnikovo
# Processing Record 37 of Set 3 | winnemucca
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | cap malheureux
# Processing Record 40 of Set 3 | semey
# Processing Record 41 of Set 3 | broome
# Processing Record 42 of Set 3 | kalmunai
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | tahe
# Processing Record 45 of Set 3 | isangel
# Processing Record 46 of Set 3 | yarada
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | gamba
# Processing Record 49 of Set 3 | muros
# Processing Record 50 of Set 3 | nouadhibou
# Processing Record 1 of Set 4 | cotonou
# Processing Record 2 of Set 4 | calabozo
# Processing Record 3 of Set 4 | yaan
# Processing Record 4 of Set 4 | kenai
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | rawlins
# Processing Record 7 of Set 4 | amazar
# Processing Record 8 of Set 4 | albany
# Processing Record 9 of Set 4 | fare
# Processing Record 10 of Set 4 | bulgan
# Processing Record 11 of Set 4 | oranjemund
# Processing Record 12 of Set 4 | baykit
# Processing Record 13 of Set 4 | paamiut
# Processing Record 14 of Set 4 | boulder city
# Processing Record 15 of Set 4 | mount gambier
# Processing Record 16 of Set 4 | luderitz
# Processing Record 17 of Set 4 | fier
# Processing Record 18 of Set 4 | lumsden
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | makakilo city
# Processing Record 22 of Set 4 | bedesa
# Processing Record 23 of Set 4 | faanui
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | toora-khem
# Processing Record 26 of Set 4 | kyren
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | camacha
# Processing Record 30 of Set 4 | esso
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | arlit
# Processing Record 33 of Set 4 | shubarshi
# Processing Record 34 of Set 4 | orange
# Processing Record 35 of Set 4 | butembo
# Processing Record 36 of Set 4 | vanavara
# Processing Record 37 of Set 4 | souillac
# Processing Record 38 of Set 4 | taoudenni
# Processing Record 39 of Set 4 | hualmay
# Processing Record 40 of Set 4 | ampanihy
# Processing Record 41 of Set 4 | esil
# Processing Record 42 of Set 4 | alice springs
# Processing Record 43 of Set 4 | afrikanda
# Processing Record 44 of Set 4 | aquin
# Processing Record 45 of Set 4 | torbay
# Processing Record 46 of Set 4 | labrea
# Processing Record 47 of Set 4 | igrim
# Processing Record 48 of Set 4 | dolores
# Processing Record 49 of Set 4 | sisimiut
# Processing Record 50 of Set 4 | bubaque
# Processing Record 1 of Set 5 | ballina
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 5 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 5 | acajutla
# Processing Record 7 of Set 5 | port elizabeth
# Processing Record 8 of Set 5 | satna
# Processing Record 9 of Set 5 | rincon
# Processing Record 10 of Set 5 | bacalan
# Processing Record 11 of Set 5 | hirara
# Processing Record 12 of Set 5 | santa maria
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | campo verde
# Processing Record 15 of Set 5 | yerbogachen
# Processing Record 16 of Set 5 | saurimo
# Processing Record 17 of Set 5 | koungou
# Processing Record 18 of Set 5 | hovd
# Processing Record 19 of Set 5 | lorengau
# Processing Record 20 of Set 5 | tilichiki
# Processing Record 21 of Set 5 | mehamn
# Processing Record 22 of Set 5 | pimentel
# Processing Record 23 of Set 5 | medea
# Processing Record 24 of Set 5 | qasigiannguit
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | tiznit
# Processing Record 27 of Set 5 | saint-denis
# Processing Record 28 of Set 5 | husavik
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | golfito
# Processing Record 31 of Set 5 | tigre
# Processing Record 32 of Set 5 | luau
# Processing Record 33 of Set 5 | longyan
# Processing Record 34 of Set 5 | henties bay
# Processing Record 35 of Set 5 | adrar
# Processing Record 36 of Set 5 | jinji
# Processing Record 37 of Set 5 | berdigestyakh
# Processing Record 38 of Set 5 | mokolo
# Processing Record 39 of Set 5 | narsaq
# Processing Record 40 of Set 5 | pangnirtung
# Processing Record 41 of Set 5 | bonavista
# Processing Record 42 of Set 5 | dennery
# Processing Record 43 of Set 5 | healdsburg
# Processing Record 44 of Set 5 | nikolskoye
# Processing Record 45 of Set 5 | acapulco
# Processing Record 46 of Set 5 | dzemul
# Processing Record 47 of Set 5 | maldonado
# Processing Record 48 of Set 5 | nara
# Processing Record 49 of Set 5 | fortuna
# Processing Record 50 of Set 5 | nuuk
# Processing Record 1 of Set 6 | saint anthony
# Processing Record 2 of Set 6 | tiksi
# Processing Record 3 of Set 6 | hasaki
# Processing Record 4 of Set 6 | moose factory
# Processing Record 5 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 6 of Set 6 | cayhagan
# Processing Record 7 of Set 6 | bathsheba
# Processing Record 8 of Set 6 | nata
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | hadejia
# Processing Record 11 of Set 6 | hay river
# Processing Record 12 of Set 6 | vallenar
# Processing Record 13 of Set 6 | altay
# Processing Record 14 of Set 6 | zabol
# Processing Record 15 of Set 6 | port blair
# Processing Record 16 of Set 6 | tucumcari
# Processing Record 17 of Set 6 | dingle
# Processing Record 18 of Set 6 | grand gaube
# Processing Record 19 of Set 6 | kathu
# Processing Record 20 of Set 6 | cabo san lucas
# Processing Record 21 of Set 6 | beidao
# Processing Record 22 of Set 6 | rocha
# Processing Record 23 of Set 6 | puerto ayora
# Processing Record 24 of Set 6 | nanortalik
# Processing Record 25 of Set 6 | vostok
# Processing Record 26 of Set 6 | deputatskiy
# Processing Record 27 of Set 6 | nehe
# Processing Record 28 of Set 6 | touros
# Processing Record 29 of Set 6 | hambantota
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | cooma
# Processing Record 32 of Set 6 | semnan
# Processing Record 33 of Set 6 | liberty
# Processing Record 34 of Set 6 | saint-pierre
# Processing Record 35 of Set 6 | karratha
# Processing Record 36 of Set 6 | sala
# Processing Record 37 of Set 6 | longyearbyen
# Processing Record 38 of Set 6 | ostrovnoy
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | tahoua
# Processing Record 41 of Set 6 | denpasar
# Processing Record 42 of Set 6 | saint pete beach
# Processing Record 43 of Set 6 | alofi
# Processing Record 44 of Set 6 | seoul
# Processing Record 45 of Set 6 | fallon
# Processing Record 46 of Set 6 | kalianget
# Processing Record 47 of Set 6 | senmonorom
# City not found. Skipping...
# Processing Record 48 of Set 6 | boffa
# Processing Record 49 of Set 6 | bambous virieux
# Processing Record 50 of Set 6 | boguchany
# Processing Record 1 of Set 7 | ulladulla
# Processing Record 2 of Set 7 | roald
# Processing Record 3 of Set 7 | bosaso
# Processing Record 4 of Set 7 | valparaiso
# Processing Record 5 of Set 7 | mecca
# Processing Record 6 of Set 7 | khatanga
# Processing Record 7 of Set 7 | ishigaki
# Processing Record 8 of Set 7 | sompeta
# Processing Record 9 of Set 7 | waipawa
# Processing Record 10 of Set 7 | blackfoot
# Processing Record 11 of Set 7 | georgetown
# Processing Record 12 of Set 7 | molchanovo
# Processing Record 13 of Set 7 | dunedin
# Processing Record 14 of Set 7 | pevek
# Processing Record 15 of Set 7 | cayenne
# Processing Record 16 of Set 7 | krasnoarmeysk
# Processing Record 17 of Set 7 | puerto narino
# Processing Record 18 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 7 | mahebourg
# Processing Record 20 of Set 7 | mednogorskiy
# Processing Record 21 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 7 | hefei
# Processing Record 23 of Set 7 | port lincoln
# Processing Record 24 of Set 7 | cordoba
# Processing Record 25 of Set 7 | rajpipla
# Processing Record 26 of Set 7 | miri
# Processing Record 27 of Set 7 | khovu-aksy
# Processing Record 28 of Set 7 | clyde river
# Processing Record 29 of Set 7 | villa bruzual
# Processing Record 30 of Set 7 | cidreira
# Processing Record 31 of Set 7 | clermont
# Processing Record 32 of Set 7 | lorica
# Processing Record 33 of Set 7 | novyy urengoy
# Processing Record 34 of Set 7 | saint-georges
# Processing Record 35 of Set 7 | morros
# Processing Record 36 of Set 7 | bud
# Processing Record 37 of Set 7 | great falls
# Processing Record 38 of Set 7 | udachnyy
# Processing Record 39 of Set 7 | port augusta
# Processing Record 40 of Set 7 | soe
# Processing Record 41 of Set 7 | saint george
# Processing Record 42 of Set 7 | ca mau
# Processing Record 43 of Set 7 | eseka
# Processing Record 44 of Set 7 | kudahuvadhoo
# Processing Record 45 of Set 7 | kologriv
# Processing Record 46 of Set 7 | celestun
# Processing Record 47 of Set 7 | rock springs
# Processing Record 48 of Set 7 | shaoyang
# Processing Record 49 of Set 7 | wanning
# Processing Record 50 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 8 | tymovskoye
# Processing Record 2 of Set 8 | muscat
# Processing Record 3 of Set 8 | dicabisagan
# Processing Record 4 of Set 8 | lompoc
# Processing Record 5 of Set 8 | poltava
# Processing Record 6 of Set 8 | general roca
# Processing Record 7 of Set 8 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 8 of Set 8 | grindavik
# Processing Record 9 of Set 8 | leszno
# Processing Record 10 of Set 8 | beruwala
# Processing Record 11 of Set 8 | tevriz
# Processing Record 12 of Set 8 | vila velha
# Processing Record 13 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 8 | margate
# Processing Record 15 of Set 8 | richard toll
# City not found. Skipping...
# Processing Record 16 of Set 8 | leningradskiy
# Processing Record 17 of Set 8 | champerico
# Processing Record 18 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 8 | macedo de cavaleiros
# Processing Record 20 of Set 8 | nome
# Processing Record 21 of Set 8 | brownwood
# Processing Record 22 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 8 | necochea
# Processing Record 24 of Set 8 | port hedland
# Processing Record 25 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 8 | katsuura
# Processing Record 28 of Set 8 | kawalu
# Processing Record 29 of Set 8 | khonsa
# Processing Record 30 of Set 8 | darnah
# Processing Record 31 of Set 8 | tiebissou
# Processing Record 32 of Set 8 | verkhnevilyuysk
# Processing Record 33 of Set 8 | mayo
# Processing Record 34 of Set 8 | barra patuca
# Processing Record 35 of Set 8 | meulaboh
# Processing Record 36 of Set 8 | nemuro
# Processing Record 37 of Set 8 | sibu
# Processing Record 38 of Set 8 | maroantsetra
# Processing Record 39 of Set 8 | vao
# Processing Record 40 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 8 | chengde
# Processing Record 42 of Set 8 | port-gentil
# Processing Record 43 of Set 8 | hinton
# Processing Record 44 of Set 8 | vaitape
# Processing Record 45 of Set 8 | fairbanks
# Processing Record 46 of Set 8 | madaoua
# Processing Record 47 of Set 8 | serenje
# Processing Record 48 of Set 8 | qaqortoq
# Processing Record 49 of Set 8 | puksoozero
# Processing Record 50 of Set 8 | jiayuguan
# Processing Record 1 of Set 9 | san quintin
# Processing Record 2 of Set 9 | san ignacio
# Processing Record 3 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 4 of Set 9 | conceicao do araguaia
# Processing Record 5 of Set 9 | acari
# Processing Record 6 of Set 9 | shimoda
# Processing Record 7 of Set 9 | camapua
# Processing Record 8 of Set 9 | carbonia
# Processing Record 9 of Set 9 | marzuq
# Processing Record 10 of Set 9 | aksarka
# Processing Record 11 of Set 9 | bolotnoye
# Processing Record 12 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 9 | codajas
# Processing Record 14 of Set 9 | lubon
# Processing Record 15 of Set 9 | shingu
# Processing Record 16 of Set 9 | nantucket
# Processing Record 17 of Set 9 | taltal
# Processing Record 18 of Set 9 | laguna de perlas
# Processing Record 19 of Set 9 | buala
# Processing Record 20 of Set 9 | sumenep
# Processing Record 21 of Set 9 | camargo
# Processing Record 22 of Set 9 | yar-sale
# Processing Record 23 of Set 9 | kruisfontein
# Processing Record 24 of Set 9 | hailar
# Processing Record 25 of Set 9 | shenjiamen
# Processing Record 26 of Set 9 | chongwe
# Processing Record 27 of Set 9 | drezdenko
# Processing Record 28 of Set 9 | massakory
# Processing Record 29 of Set 9 | menongue
# Processing Record 30 of Set 9 | tuatapere
# Processing Record 31 of Set 9 | merta
# Processing Record 32 of Set 9 | xining
# Processing Record 33 of Set 9 | ouadda
# Processing Record 34 of Set 9 | bagdarin
# Processing Record 35 of Set 9 | half moon bay
# Processing Record 36 of Set 9 | nadadores
# Processing Record 37 of Set 9 | cabedelo
# Processing Record 38 of Set 9 | diapaga
# Processing Record 39 of Set 9 | mankachar
# Processing Record 40 of Set 9 | sarangani
# Processing Record 41 of Set 9 | le vauclin
# Processing Record 42 of Set 9 | presidencia roque saenz pena
# Processing Record 43 of Set 9 | biryukove
# Processing Record 44 of Set 9 | kholm-zhirkovskiy
# Processing Record 45 of Set 9 | truth or consequences
# Processing Record 46 of Set 9 | sinjar
# Processing Record 47 of Set 9 | benguela
# Processing Record 48 of Set 9 | talnakh
# Processing Record 49 of Set 9 | oistins
# Processing Record 50 of Set 9 | ukiah
# Processing Record 1 of Set 10 | severo-kurilsk
# Processing Record 2 of Set 10 | kloulklubed
# Processing Record 3 of Set 10 | vardo
# Processing Record 4 of Set 10 | kadiri
# Processing Record 5 of Set 10 | praia da vitoria
# Processing Record 6 of Set 10 | bekwai
# Processing Record 7 of Set 10 | puerto colombia
# Processing Record 8 of Set 10 | launceston
# Processing Record 9 of Set 10 | camana
# Processing Record 10 of Set 10 | trincomalee
# Processing Record 11 of Set 10 | tazovskiy
# Processing Record 12 of Set 10 | martapura
# Processing Record 13 of Set 10 | antofagasta
# Processing Record 14 of Set 10 | kieta
# Processing Record 15 of Set 10 | jermuk
# Processing Record 16 of Set 10 | padang
# Processing Record 17 of Set 10 | ondjiva
# Processing Record 18 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 10 | boatlaname
# City not found. Skipping...
# Processing Record 20 of Set 10 | espanola
# Processing Record 21 of Set 10 | namibe
# Processing Record 22 of Set 10 | tessalit
# Processing Record 23 of Set 10 | salalah
# Processing Record 24 of Set 10 | borger
# Processing Record 25 of Set 10 | appingedam
# Processing Record 26 of Set 10 | paita
# Processing Record 27 of Set 10 | winslow
# Processing Record 28 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 10 | kangaatsiaq
# Processing Record 30 of Set 10 | amos
# Processing Record 31 of Set 10 | pringsewu
# Processing Record 32 of Set 10 | bakchar
# Processing Record 33 of Set 10 | northam
# Processing Record 34 of Set 10 | pimenta bueno
# Processing Record 35 of Set 10 | flinders
# Processing Record 36 of Set 10 | puerto rondon
# Processing Record 37 of Set 10 | ngunguru
# Processing Record 38 of Set 10 | salinopolis
# Processing Record 39 of Set 10 | yumen
# Processing Record 40 of Set 10 | astara
# Processing Record 41 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 42 of Set 10 | ambon
# Processing Record 43 of Set 10 | alta floresta
# Processing Record 44 of Set 10 | frystak
# Processing Record 45 of Set 10 | moskhokhorion
# City not found. Skipping...
# Processing Record 46 of Set 10 | kaitangata
# Processing Record 47 of Set 10 | constitucion
# Processing Record 48 of Set 10 | lohja
# Processing Record 49 of Set 10 | kaduy
# Processing Record 50 of Set 10 | windsor
# Processing Record 1 of Set 11 | dongying
# Processing Record 2 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 11 | lerwick
# Processing Record 4 of Set 11 | green river
# Processing Record 5 of Set 11 | iberia
# Processing Record 6 of Set 11 | keratea
# Processing Record 7 of Set 11 | poli
# Processing Record 8 of Set 11 | bermejo
# Processing Record 9 of Set 11 | hokitika
# Processing Record 10 of Set 11 | mananjary
# Processing Record 11 of Set 11 | moussoro
# Processing Record 12 of Set 11 | aldan
# Processing Record 13 of Set 11 | beringovskiy
# Processing Record 14 of Set 11 | bam
# Processing Record 15 of Set 11 | conceicao do mato dentro
# Processing Record 16 of Set 11 | sovetskiy
# Processing Record 17 of Set 11 | nizhniy tsasuchey
# Processing Record 18 of Set 11 | villa carlos paz
# Processing Record 19 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 11 | kingaroy
# Processing Record 21 of Set 11 | athens
# Processing Record 22 of Set 11 | san francisco
# Processing Record 23 of Set 11 | springbok
# Processing Record 24 of Set 11 | moree
# Processing Record 25 of Set 11 | chapais
# Processing Record 26 of Set 11 | ayan
# Processing Record 27 of Set 11 | guerrero negro
# Processing Record 28 of Set 11 | merauke
# Processing Record 29 of Set 11 | bandarbeyla
# Processing Record 30 of Set 11 | huanren
# Processing Record 31 of Set 11 | omsukchan
# Processing Record 32 of Set 11 | orahovac
# Processing Record 33 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 11 | port said
# Processing Record 35 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 11 | jishou
# Processing Record 37 of Set 11 | bend
# Processing Record 38 of Set 11 | hauterive
# Processing Record 39 of Set 11 | lasa
# Processing Record 40 of Set 11 | kismayo
# Processing Record 41 of Set 11 | dawson creek
# Processing Record 42 of Set 11 | ylivieska
# Processing Record 43 of Set 11 | kahului
# Processing Record 44 of Set 11 | ugoofaaru
# Processing Record 45 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 46 of Set 11 | roebourne
# Processing Record 47 of Set 11 | komsomolskiy
# Processing Record 48 of Set 11 | ashland
# Processing Record 49 of Set 11 | muli
# Processing Record 50 of Set 11 | kamyshevatskaya
# Processing Record 1 of Set 12 | tual
# Processing Record 2 of Set 12 | acarau
# Processing Record 3 of Set 12 | zambezi
# Processing Record 4 of Set 12 | zhigansk
# Processing Record 5 of Set 12 | santa barbara
# Processing Record 6 of Set 12 | mgachi
# Processing Record 7 of Set 12 | norrkoping
# Processing Record 8 of Set 12 | presque isle
# Processing Record 9 of Set 12 | preston
# Processing Record 10 of Set 12 | comodoro rivadavia
# Processing Record 11 of Set 12 | xuddur
# Processing Record 12 of Set 12 | san juan
# Processing Record 13 of Set 12 | bundaberg
# Processing Record 14 of Set 12 | prince rupert
# Processing Record 15 of Set 12 | stornoway
# Processing Record 16 of Set 12 | kailua
# Processing Record 17 of Set 12 | ouargaye
# Processing Record 18 of Set 12 | kudymkar
# Processing Record 19 of Set 12 | manokwari
# Processing Record 20 of Set 12 | sidi ali
# Processing Record 21 of Set 12 | cam ranh
# Processing Record 22 of Set 12 | chara
# Processing Record 23 of Set 12 | inuvik
# Processing Record 24 of Set 12 | ouango
# Processing Record 25 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 12 | san policarpo
# Processing Record 27 of Set 12 | thinadhoo
# Processing Record 28 of Set 12 | pacific grove
# Processing Record 29 of Set 12 | ambovombe
# Processing Record 30 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 12 | hami
# Processing Record 32 of Set 12 | dorado
# Processing Record 33 of Set 12 | sal rei
# Processing Record 34 of Set 12 | jaciara
# Processing Record 35 of Set 12 | san vicente
# Processing Record 36 of Set 12 | matay
# Processing Record 37 of Set 12 | cabo rojo
# Processing Record 38 of Set 12 | turan
# Processing Record 39 of Set 12 | tura
# Processing Record 40 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 12 | sur
# Processing Record 42 of Set 12 | tabou
# Processing Record 43 of Set 12 | arti
# Processing Record 44 of Set 12 | gilbues
# Processing Record 45 of Set 12 | verkh-usugli
# Processing Record 46 of Set 12 | bonthe
# Processing Record 47 of Set 12 | furstenwalde
# Processing Record 48 of Set 12 | isla mujeres
# Processing Record 49 of Set 12 | pisco
# Processing Record 50 of Set 12 | yavaros
# Processing Record 1 of Set 13 | tecoanapa
# Processing Record 2 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 13 | strezhevoy
# Processing Record 4 of Set 13 | rumes
# Processing Record 5 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 13 | peoria
# Processing Record 7 of Set 13 | burnie
# Processing Record 8 of Set 13 | verkhnyaya toyma
# Processing Record 9 of Set 13 | balkhash
# Processing Record 10 of Set 13 | horodkivka
# Processing Record 11 of Set 13 | chardara
# Processing Record 12 of Set 13 | zhigalovo
# Processing Record 13 of Set 13 | qarqin
# Processing Record 14 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 15 of Set 13 | resistencia
# Processing Record 16 of Set 13 | babu
# Processing Record 17 of Set 13 | nizhniy kuranakh
# Processing Record 18 of Set 13 | horizontina
# Processing Record 19 of Set 13 | atar
# Processing Record 20 of Set 13 | tambopata
# Processing Record 21 of Set 13 | kyra
# Processing Record 22 of Set 13 | tocopilla
# Processing Record 23 of Set 13 | vila do maio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 575

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Victoria  22.2855  114.1577     61.25        79          47
# 1       Ushuaia -54.8000  -68.3000     49.66        87          75
# 2     Cape Town -33.9258   18.4232     67.87        86           0
# 3         Lagoa  39.0500  -27.9833     57.07        71           6
# 4        Atuona  -9.8000 -139.0333     79.02        75          18
# 5   Port Alfred -33.5906   26.8910     73.18        88           7
# 6  Mizan Teferi   6.9833   35.5833     65.89        71         100
# 7          Naze  28.3667  129.4833     56.32        55           0
# 8      Bengkulu  -3.8004  102.2655     77.99        74          90
# 9       Qaanaaq  77.4840  -69.3632    -14.31        58          99
#
#    Wind Speed Country                 Date
# 0        5.01      HK  2022-02-25 01:23:44
# 1       10.36      AR  2022-02-25 01:27:07
# 2       11.50      ZA  2022-02-25 01:25:48
# 3        9.66      PT  2022-02-25 01:27:08
# 4       20.51      PF  2022-02-25 01:27:09
# 5       18.75      ZA  2022-02-25 01:27:09
# 6        1.43      ET  2022-02-25 01:27:10
# 7       13.15      JP  2022-02-25 01:27:10
# 8        4.65      ID  2022-02-25 01:27:11
# 9        5.77      GL  2022-02-25 01:27:11

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
